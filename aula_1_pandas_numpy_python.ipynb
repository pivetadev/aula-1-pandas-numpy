# %% [markdown]
# # Introdução ao Pandas e Numpy para manipulação de dados
#
# O que seria esse tal do pandas?
#
# Imagine que você tem uma grande quantidade de dados, como uma planilha cheia de informações ou uma lista gigante de números. Agora, você quer organizar, manipular e analisar esses dados de uma maneira mais eficiente do que simplesmente olhar para cada um manualmente ou usar ferramentas limitadas, como calculadoras ou planilhas.
#
# O Pandas é como uma superplanilha no mundo da programação. Ele te ajuda a lidar com grandes conjuntos de dados de forma organizada, como se estivesse usando uma tabela do Excel, mas com muito mais poder e flexibilidade.
#
# Com o Pandas, você pode:
#
#   1. Filtrar os dados que quer analisar, sem precisar excluir nada.
#   2. Encontrar rapidamente informações específicas em uma grande tabela.
#   3. Fazer cálculos complexos em várias colunas ou linhas ao mesmo tempo.
#   4. Organizar os dados de diferentes maneiras (como ordenando ou agrupando).
#
# É como um assistente inteligente que pega seus dados e permite que você faça perguntas como: “Qual foi o total de vendas no último mês?” ou “Quantas pessoas têm mais de 30 anos nesta lista?”
#
# Em resumo, Pandas é a ferramenta ideal para tratamento de dados. Ele permite que você organize, limpe, transforme e analise grandes conjuntos de dados de forma eficiente. Com Pandas, você consegue:
#
#     1. Limpar dados desorganizados (remover duplicatas, lidar com valores faltantes).
#     2. Transformar dados(alterar formatos, reorganizar colunas, etc.).
#     3. Analisar dados de maneira mais aprofundada **(calcular médias, somas, agrupar informações).
#
# Para trabalhar com dados no formato de tabelas, facilitando todo o processo de preparação dos dados para uma análise mais avançada.

# %% [markdown]
# #O que é o NumPy?
#
# O NumPy é como a "calculadora científica" do mundo dos dados. Quando você está lidando com muitos números (imagine uma tabela cheia de números), o NumPy te ajuda a fazer operações matemáticas rapidamente e de forma eficiente. Ele não organiza os dados em tabelas como o Pandas, mas funciona mais como uma caixa de ferramentas para fazer contas com os dados.
#
# Com o NumPy, você pode:
#
#     1. Somar, multiplicar, dividir números em grandes quantidades, tudo de uma vez.
#     2. Fazer operações matemáticas complexas, como calcular a média ou encontrar padrões em grandes grupos de números.
#     3. Lidar com grandes volumes de dados numéricos de maneira muito mais rápida do que fazendo manualmente.
#
# Se o Pandas é seu assistente para organizar dados, o NumPy é sua ferramenta para lidar com números e fazer cálculos em grande escala.
#
# Então, Pandas te ajuda a organizar e filtrar os dados, e o NumPy te dá ferramentas poderosas para fazer cálculos com esses dados. Juntos, eles tornam o trabalho com dados muito mais fácil e eficiente!

# %%
#Importando bibliotecas
import pandas as pd
import os

# %% [markdown]
# # **A biblioteca os**
# Em Python é uma ferramenta que permite interagir diretamente com o sistema operacional do computador. Pense nela como uma ponte entre o código Python e os recursos do seu computador, como arquivos, pastas e comandos do sistema.
#
# Com a biblioteca os, você pode:
#
#     1. Criar, renomear ou remover pastas e arquivos.
#     2. Navegar entre diferentes diretórios (pastas) do seu sistema.
#     3. Obter informações sobre arquivos, como tamanho, data de modificação, etc.
#     4. Executar comandos do sistema, como abrir um programa ou rodar scripts.

# %% [markdown]
# A biblioteca os em Python é uma ferramenta que permite interagir diretamente com o sistema operacional do computador. Pense nela como uma ponte entre o código Python e os recursos do seu computador, como arquivos, pastas e comandos do sistema.
#
# Com a biblioteca os, você pode:
#
#     Criar, renomear ou remover pastas e arquivos.
#     Navegar entre diferentes diretórios (pastas) do seu sistema.
#     Obter informações sobre arquivos, como tamanho, data de modificação, etc.
#     Executar comandos do sistema, como abrir um programa ou rodar scripts.

# %%
#Leitura do arquivo
data = pd.read_csv(r'transito/acidentes2024.csv', encoding='latin1', on_bad_lines='skip', sep=';')

# %%
data = pd.read_csv(r'transito/acidentes2024.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-64-33863fd0b724> in <cell line: 1>()
# ----> 1 data = pd.read_csv(r'transito/acidentes2024.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
#     947
# --> 948     return _read(filepath_or_buffer, kwds)
#     949
#     950
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     # Create the parser.
# --> 611     parser = TextFileReader(filepath_or_buffer, **kwds)
#     612
#     613     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1446
#    1447         self.handles: IOHandles | None = None
# -> 1448         self._engine = self._make_engine(f, self.engine)
#    1449
#    1450     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1721
#    1722         try:
# -> 1723             return mapping[engine](f, **self.options)
#    1724         except Exception:
#    1725             if self.handles is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      91             # Fail here loudly instead of in cython after reading
#      92             import_optional_dependency("pyarrow")
# ---> 93         self._reader = parsers.TextReader(src, **kwds)
#      94
#      95         self.unnamed_cols = self._reader.unnamed_cols
#
# parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe3 in position 554: invalid continuation byte

# %%
#Print do arquivo
data
# Out:
#               id    pesid data_inversa     dia_semana   horario  uf   br   km  \
# 0       571789.0  1269011   2024-01-01  segunda-feira  03:56:00  ES  101   38
# 1       571804.0  1269118   2024-01-01  segunda-feira  04:50:00  PI  343  185
# 2       571806.0  1269735   2024-01-01  segunda-feira  04:30:00  BA  116  578
# 3       571818.0  1269075   2024-01-01  segunda-feira  06:30:00  SE  101   18
# 4       571838.0  1269159   2024-01-01  segunda-feira  05:00:00  MT  364  240
# ...          ...      ...          ...            ...       ...  ..  ...  ...
# 128121  627985.0  1406814   2024-07-14        domingo  23:30:00  RO  364  388
# 128122  627985.0  1406813   2024-07-14        domingo  23:30:00  RO  364  388
# 128123  627985.0  1406812   2024-07-14        domingo  23:30:00  RO  364  388
# 128124  627985.0  1406811   2024-07-14        domingo  23:30:00  RO  364  388
# 128125  627985.0  1406810   2024-07-14        domingo  23:30:00  RO  364  388
#
#                   municipio  \
# 0        CONCEICAO DA BARRA
# 1                  PIRIPIRI
# 2                   BREJOES
# 3          MALHADA DOS BOIS
# 4              RONDONOPOLIS
# ...                     ...
# 128121  OURO PRETO DO OESTE
# 128122  OURO PRETO DO OESTE
# 128123  OURO PRETO DO OESTE
# 128124  OURO PRETO DO OESTE
# 128125  OURO PRETO DO OESTE
#
#                                            causa_acidente  ...       sexo  \
# 0                                  Ultrapassagem Indevida  ...  Masculino
# 1                             Manobra de mudança de faixa  ...  Masculino
# 2                        Ingestão de álcool pelo condutor  ...  Masculino
# 3                Reação tardia ou ineficiente do condutor  ...  Masculino
# 4       Condutor deixou de manter distância do veículo...  ...  Masculino
# ...                                                   ...  ...        ...
# 128121                     Ausência de reação do condutor  ...  Masculino
# 128122                     Ausência de reação do condutor  ...  Masculino
# 128123                     Ausência de reação do condutor  ...  Masculino
# 128124                     Ausência de reação do condutor  ...   Feminino
# 128125                     Ausência de reação do condutor  ...   Feminino
#
#        ilesos feridos_leves feridos_graves mortos      latitude     longitude  \
# 0           1             0              0      0     -18,48261     -39,92379
# 1           1             0              0      0   -4,29603281  -41,76732659
# 2           1             0              0      0  -13,07158302   -39,9611107
# 3           0             0              1      0  -10,35601949  -36,90552235
# 4           1             0              0      0  -16,17914141  -54,78905337
# ...       ...           ...            ...    ...           ...           ...
# 128121      1             0              0      0  -10,70116422  -62,26238327
# 128122      1             0              0      0  -10,70116422  -62,26238327
# 128123      0             0              0      1  -10,70116422  -62,26238327
# 128124      0             0              1      0  -10,70116422  -62,26238327
# 128125      0             0              1      0  -10,70116422  -62,26238327
#
#        regional  delegacia             uop
# 0       SPRF-ES   DEL04-ES  UOP02-DEL04-ES
# 1       SPRF-PI   DEL02-PI  UOP01-DEL02-PI
# 2       SPRF-BA   DEL03-BA  UOP02-DEL03-BA
# 3       SPRF-SE   DEL02-SE  UOP02-DEL02-SE
# 4       SPRF-MT   DEL02-MT  UOP01-DEL02-MT
# ...         ...        ...             ...
# 128121  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128122  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128123  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128124  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128125  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
#
# [128126 rows x 35 columns]

# %% [markdown]
# encoding='latin1'
#
#   O que é?: O parâmetro encoding define a codificação de caracteres a ser usada ao ler o arquivo. latin1 (também conhecido como ISO-8859-1) é uma codificação que inclui os caracteres da língua portuguesa, entre outras línguas ocidentais. Essa codificação é frequentemente usada em arquivos que contêm caracteres especiais que não são bem representados em UTF-8.

# %% [markdown]
# on_bad_lines='skip'
#
#   O que é?: O parâmetro on_bad_lines é usado para lidar com linhas problemáticas no arquivo que não podem ser processadas corretamente. O valor 'skip' instrui o Pandas a ignorar essas linhas problemáticas durante a leitura do arquivo.

# %% [markdown]
# sep=' ; '
#
#   O que é?: O parâmetro sep define o delimitador usado para separar os campos nas linhas do arquivo. No caso de sep=';', isso indica que o arquivo utiliza um ponto e vírgula (;) como delimitador em vez da vírgula padrão (,) comumente utilizada em arquivos CSV.

# %%
df = pd.read_csv('https://drive.google.com/file/d/1vm2TETMK-CyEM5duGSu4EUcNf7EtECzG/view?usp=drive_link', encoding='latin1', on_bad_lines='skip', sep=';')

# %%
df.head()
# Out:
#   <!DOCTYPE html><html><head><script nonce="cVgOoHGK6ri-8ss7L-4ZLA"> window['_DRIVE_VIEWER_ctiming']={}  \
# 0            window['_DRIVE_VIEWER_IVIS'] = docum...
# 1          </script><meta property="og:title" con...
# 2                                               try{
# 3  _._F_toggles_initialize=function(a){(typeof gl...
# 4                                                 /*
#
#    </script><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge  \
# 0                                                NaN
# 1  usp=embed_facebook"><link rel="shortcut icon" ...
# 2                                                NaN
# 3                    (0,_._F_toggles_initialize)([])
# 4                                                NaN
#
#   ><style nonce=kJiRnuCzWaOgrwlF7adyzg">@font-face{font-family:'Roboto'  \
# 0                                                NaN
# 1   </script><link rel="stylesheet" href="https:/...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   font-style:italic                                    font-weight:400  \
# 0               NaN                                                NaN
# 1               500  700" rel="stylesheet" nonce="kJiRnuCzWaOgrwlF7...
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
#
#   src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype')  \
# 0                                                NaN
# 1   </script><script data-id="_gd" nonce="cVgOoHG...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                     }@font-face{font-family:'Roboto'       font-style:normal  \
# 0                                                NaN                     NaN
# 1  </script><script nonce="cVgOoHGK6ri-8ss7L-4ZLA...   _docs_flag_cek= null
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#                                      font-weight:300  \
# 0                                                NaN
# 1   if (window['DOCS_timing']) {DOCS_timing['ifdl...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype')  \
# 0                                                NaN
# 1  }</script><script nonce="cVgOoHGK6ri-8ss7L-4ZL...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype')  \
# 0                                                NaN
# 1  /_/scs/abc-static/_/js/k=gapi.gapi.en.SpvAvsXf...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   }@font-face{font-family:'Roboto'.2           font-style:normal.2  \
# 0                                NaN                           NaN
# 1          this.gbar_=this.gbar_||{}  (function(_){var window=this
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#   font-weight:500  \
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
#   src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype')  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   }@font-face{font-family:'Roboto'.3 font-style:normal.3 font-weight:700  \
# 0                                NaN                 NaN             NaN
# 1                                NaN                 NaN             NaN
# 2                                NaN                 NaN             NaN
# 3                                NaN                 NaN             NaN
# 4                                NaN                 NaN             NaN
#
#   src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype')  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   }</style><meta name="referrer" content="origin"><title>datatran2024.csv - Google é²ç«¯ç¡¬ç¢</title><script nonce="cVgOoHGK6ri-8ss7L-4ZLA">
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
import os
import pandas as pd

lista_dataframe = []
lista_nome = []
diretorio = "transito"  # Certifique-se de que esse diretório existe

# Corrigindo o nome da função e o método para verificar a extensão
for arq in os.listdir(diretorio):
    if arq.endswith(".csv"):
        nome_arquivo = os.path.join(diretorio, arq)  # Usando os.path.join para formar o caminho
        nome_df = pd.read_csv(nome_arquivo, sep=';', encoding='latin-1')  # caminho completo
        print("Nome do Arquivo: ", arq)
        lista_dataframe.append(nome_df)
        x = arq.rfind(".")
        lista_nome.append(arq[:x])
        print(arq[:x])

# Exibindo a lista de nomes
print("Nomes dos arquivos (sem extensão):", lista_nome)
# Out:
# Nome do Arquivo:  acidentes2024.csv
# acidentes2024
# Nome do Arquivo:  acidentes2024_todas_causas_tipos.csv
# acidentes2024_todas_causas_tipos
# Nome do Arquivo:  datatran2024.csv
# datatran2024
# Nomes dos arquivos (sem extensão): ['acidentes2024', 'acidentes2024_todas_causas_tipos', 'datatran2024']

# %%
#quantidade de item na lista
len(lista_dataframe[0])
# Out:
# 128126

# %%
#arquivo 1
lista_dataframe[0]
# Out:
#               id    pesid data_inversa     dia_semana   horario  uf   br   km  \
# 0       571789.0  1269011   2024-01-01  segunda-feira  03:56:00  ES  101   38
# 1       571804.0  1269118   2024-01-01  segunda-feira  04:50:00  PI  343  185
# 2       571806.0  1269735   2024-01-01  segunda-feira  04:30:00  BA  116  578
# 3       571818.0  1269075   2024-01-01  segunda-feira  06:30:00  SE  101   18
# 4       571838.0  1269159   2024-01-01  segunda-feira  05:00:00  MT  364  240
# ...          ...      ...          ...            ...       ...  ..  ...  ...
# 128121  627985.0  1406814   2024-07-14        domingo  23:30:00  RO  364  388
# 128122  627985.0  1406813   2024-07-14        domingo  23:30:00  RO  364  388
# 128123  627985.0  1406812   2024-07-14        domingo  23:30:00  RO  364  388
# 128124  627985.0  1406811   2024-07-14        domingo  23:30:00  RO  364  388
# 128125  627985.0  1406810   2024-07-14        domingo  23:30:00  RO  364  388
#
#                   municipio  \
# 0        CONCEICAO DA BARRA
# 1                  PIRIPIRI
# 2                   BREJOES
# 3          MALHADA DOS BOIS
# 4              RONDONOPOLIS
# ...                     ...
# 128121  OURO PRETO DO OESTE
# 128122  OURO PRETO DO OESTE
# 128123  OURO PRETO DO OESTE
# 128124  OURO PRETO DO OESTE
# 128125  OURO PRETO DO OESTE
#
#                                            causa_acidente  ...       sexo  \
# 0                                  Ultrapassagem Indevida  ...  Masculino
# 1                             Manobra de mudança de faixa  ...  Masculino
# 2                        Ingestão de álcool pelo condutor  ...  Masculino
# 3                Reação tardia ou ineficiente do condutor  ...  Masculino
# 4       Condutor deixou de manter distância do veículo...  ...  Masculino
# ...                                                   ...  ...        ...
# 128121                     Ausência de reação do condutor  ...  Masculino
# 128122                     Ausência de reação do condutor  ...  Masculino
# 128123                     Ausência de reação do condutor  ...  Masculino
# 128124                     Ausência de reação do condutor  ...   Feminino
# 128125                     Ausência de reação do condutor  ...   Feminino
#
#        ilesos feridos_leves feridos_graves mortos      latitude     longitude  \
# 0           1             0              0      0     -18,48261     -39,92379
# 1           1             0              0      0   -4,29603281  -41,76732659
# 2           1             0              0      0  -13,07158302   -39,9611107
# 3           0             0              1      0  -10,35601949  -36,90552235
# 4           1             0              0      0  -16,17914141  -54,78905337
# ...       ...           ...            ...    ...           ...           ...
# 128121      1             0              0      0  -10,70116422  -62,26238327
# 128122      1             0              0      0  -10,70116422  -62,26238327
# 128123      0             0              0      1  -10,70116422  -62,26238327
# 128124      0             0              1      0  -10,70116422  -62,26238327
# 128125      0             0              1      0  -10,70116422  -62,26238327
#
#        regional  delegacia             uop
# 0       SPRF-ES   DEL04-ES  UOP02-DEL04-ES
# 1       SPRF-PI   DEL02-PI  UOP01-DEL02-PI
# 2       SPRF-BA   DEL03-BA  UOP02-DEL03-BA
# 3       SPRF-SE   DEL02-SE  UOP02-DEL02-SE
# 4       SPRF-MT   DEL02-MT  UOP01-DEL02-MT
# ...         ...        ...             ...
# 128121  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128122  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128123  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128124  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
# 128125  SPRF-RO   DEL03-RO  UOP02-DEL03-RO
#
# [128126 rows x 35 columns]

# %%
#arquivo 1
lista_dataframe[1]
# Out:
#               id      pesid data_inversa     dia_semana   horario  uf     br  \
# 0       571772.0  1268971.0   2024-01-01  segunda-feira  00:05:00  RJ  101.0
# 1       571774.0  1268985.0   2024-01-01  segunda-feira  00:05:00  GO  153.0
# 2       571774.0  1268985.0   2024-01-01  segunda-feira  00:05:00  GO  153.0
# 3       571777.0  1269020.0   2024-01-01  segunda-feira  01:45:00  ES  101.0
# 4       571778.0  1269028.0   2024-01-01  segunda-feira  00:45:00  SC  101.0
# ...          ...        ...          ...            ...       ...  ..    ...
# 343407  621812.0  1392084.0   2024-06-28    sexta-feira  07:10:00  SC  470.0
# 343408  621831.0  1392136.0   2024-07-28        domingo  11:30:00  AL  316.0
# 343409  621831.0  1392135.0   2024-07-28        domingo  11:30:00  AL  316.0
# 343410  621831.0  1392136.0   2024-07-28        domingo  11:30:00  AL  316.0
# 343411  621831.0  1392135.0   2024-07-28        domingo  11:30:00  AL  316.0
#
#            km municipio causa_principal  ...       sexo  ilesos feridos_leves  \
# 0       272,5    TANGUA             Sim  ...  Masculino     0.0           0.0
# 1       424,6  ANAPOLIS             Não  ...   Feminino     1.0           0.0
# 2       424,6  ANAPOLIS             Sim  ...   Feminino     1.0           0.0
# 3       264,1     SERRA             Sim  ...  Masculino     1.0           0.0
# 4         110     PENHA             Não  ...  Masculino     1.0           0.0
# ...       ...       ...             ...  ...        ...     ...           ...
# 343407   54,1  BLUMENAU             Não  ...  Masculino     1.0           0.0
# 343408    262    SATUBA             Não  ...   Feminino     0.0           1.0
# 343409    262    SATUBA             Não  ...  Masculino     0.0           0.0
# 343410    262    SATUBA             Sim  ...   Feminino     0.0           1.0
# 343411    262    SATUBA             Sim  ...  Masculino     0.0           0.0
#
#        feridos_graves mortos      latitude     longitude regional delegacia  \
# 0                 0.0    1.0  -22,72935968  -42,70112512  SPRF-RJ  DEL02-RJ
# 1                 0.0    0.0    -16,229185    -49,009797  SPRF-GO  DEL02-GO
# 2                 0.0    0.0    -16,229185    -49,009797  SPRF-GO  DEL02-GO
# 3                 0.0    0.0  -20,17292791  -40,26736384  SPRF-ES  DEL02-ES
# 4                 0.0    0.0     -26,83477    -48,706151  SPRF-SC  DEL03-SC
# ...               ...    ...           ...           ...      ...       ...
# 343407            0.0    0.0    -26,871065    -49,110374  SPRF-SC  DEL04-SC
# 343408            0.0    0.0   -9,58877051  -35,88700493  SPRF-AL  DEL02-AL
# 343409            1.0    0.0   -9,58877051  -35,88700493  SPRF-AL  DEL02-AL
# 343410            0.0    0.0   -9,58877051  -35,88700493  SPRF-AL  DEL02-AL
# 343411            1.0    0.0   -9,58877051  -35,88700493  SPRF-AL  DEL02-AL
#
#                    uop
# 0       UOP03-DEL02-RJ
# 1       UOP01-DEL02-GO
# 2       UOP01-DEL02-GO
# 3       UOP01-DEL02-ES
# 4       UOP02-DEL03-SC
# ...                ...
# 343407  UOP01-DEL04-SC
# 343408  UOP01-DEL02-AL
# 343409  UOP01-DEL02-AL
# 343410  UOP01-DEL02-AL
# 343411  UOP01-DEL02-AL
#
# [343412 rows x 37 columns]

# %%
#arquivo 1
lista_dataframe[2]
# Out:
#              id data_inversa     dia_semana   horario  uf   br    km  \
# 0      571789.0   2024-01-01  segunda-feira  03:56:00  ES  101    38
# 1      571804.0   2024-01-01  segunda-feira  04:50:00  PI  343   185
# 2      571806.0   2024-01-01  segunda-feira  04:30:00  BA  116   578
# 3      571818.0   2024-01-01  segunda-feira  06:30:00  SE  101    18
# 4      571838.0   2024-01-01  segunda-feira  05:00:00  MT  364   240
# ...         ...          ...            ...       ...  ..  ...   ...
# 47698  627756.0   2024-08-20    terça-feira  17:00:00  MG  116  13,6
# 47699  627773.0   2024-06-01         sábado  19:20:00  MG  116   422
# 47700  627777.0   2024-08-07   quarta-feira  18:10:00  RS  116   234
# 47701  627911.0   2024-08-29   quinta-feira  07:30:00  MG   40   515
# 47702  627985.0   2024-07-14        domingo  23:30:00  RO  364   388
#
#                  municipio                                     causa_acidente  \
# 0       CONCEICAO DA BARRA                             Ultrapassagem Indevida
# 1                 PIRIPIRI                        Manobra de mudança de faixa
# 2                  BREJOES                   Ingestão de álcool pelo condutor
# 3         MALHADA DOS BOIS           Reação tardia ou ineficiente do condutor
# 4             RONDONOPOLIS  Condutor deixou de manter distância do veículo...
# ...                    ...                                                ...
# 47698      AGUAS VERMELHAS           Reação tardia ou ineficiente do condutor
# 47699            ALPERCATA                                   Animais na Pista
# 47700       ESTANCIA VELHA                                   Acesso irregular
# 47701   RIBEIRAO DAS NEVES  Condutor deixou de manter distância do veículo...
# 47702  OURO PRETO DO OESTE                     Ausência de reação do condutor
#
#                         tipo_acidente  ... feridos_graves ilesos ignorados  \
# 0      Colisão lateral sentido oposto  ...              1      1         1
# 1                     Colisão frontal  ...              0      1         0
# 2                     Colisão frontal  ...              0      1         2
# 3           Saída de leito carroçável  ...              1      0         2
# 4                    Colisão traseira  ...              0      2         1
# ...                               ...  ...            ...    ...       ...
# 47698       Saída de leito carroçável  ...              0      0         0
# 47699         Atropelamento de Animal  ...              0      0         0
# 47700             Colisão transversal  ...              0      2         0
# 47701                   Engavetamento  ...              1      1         0
# 47702       Saída de leito carroçável  ...              2      2         0
#
#       feridos veiculos      latitude     longitude  regional  delegacia  \
# 0           1        3     -18,48261     -39,92379   SPRF-ES   DEL04-ES
# 1           0        2   -4,29603281  -41,76732659   SPRF-PI   DEL02-PI
# 2           0        4  -13,07158302   -39,9611107   SPRF-BA   DEL03-BA
# 3           1        3  -10,35601949  -36,90552235   SPRF-SE   DEL02-SE
# 4           0        3  -16,17914141  -54,78905337   SPRF-MT   DEL02-MT
# ...       ...      ...           ...           ...       ...        ...
# 47698       1        1    -15,804386    -41,359894   SPRF-BA   DEL08-BA
# 47699       1        1  -18,95287041  -41,95682514   SPRF-MG   DEL06-MG
# 47700       0        2  -29,65121313   -51,1444433   SPRF-RS   DEL01-RS
# 47701       2        3   -19,8090079  -44,09493479   SPRF-MG   DEL01-MG
# 47702       2        2  -10,70116422  -62,26238327   SPRF-RO   DEL03-RO
#
#                   uop
# 0      UOP02-DEL04-ES
# 1      UOP01-DEL02-PI
# 2      UOP02-DEL03-BA
# 3      UOP02-DEL02-SE
# 4      UOP01-DEL02-MT
# ...               ...
# 47698  UOP03-DEL08-BA
# 47699  UOP01-DEL06-MG
# 47700  UOP02-DEL01-RS
# 47701  UOP02-DEL01-MG
# 47702  UOP02-DEL03-RO
#
# [47703 rows x 30 columns]

# %%
lista_nome
# Out:
# ['acidentes2024', 'acidentes2024_todas_causas_tipos', 'datatran2024']

# %%
#concatenar
df_concat = pd.concat([lista_dataframe[0],lista_dataframe[1],lista_dataframe[2]])

# %%
df_concat
# Out:
#              id      pesid data_inversa     dia_semana   horario  uf     br  \
# 0      571789.0  1269011.0   2024-01-01  segunda-feira  03:56:00  ES  101.0
# 1      571804.0  1269118.0   2024-01-01  segunda-feira  04:50:00  PI  343.0
# 2      571806.0  1269735.0   2024-01-01  segunda-feira  04:30:00  BA  116.0
# 3      571818.0  1269075.0   2024-01-01  segunda-feira  06:30:00  SE  101.0
# 4      571838.0  1269159.0   2024-01-01  segunda-feira  05:00:00  MT  364.0
# ...         ...        ...          ...            ...       ...  ..    ...
# 47698  627756.0        NaN   2024-08-20    terça-feira  17:00:00  MG  116.0
# 47699  627773.0        NaN   2024-06-01         sábado  19:20:00  MG  116.0
# 47700  627777.0        NaN   2024-08-07   quarta-feira  18:10:00  RS  116.0
# 47701  627911.0        NaN   2024-08-29   quinta-feira  07:30:00  MG   40.0
# 47702  627985.0        NaN   2024-07-14        domingo  23:30:00  RO  364.0
#
#          km            municipio  \
# 0        38   CONCEICAO DA BARRA
# 1       185             PIRIPIRI
# 2       578              BREJOES
# 3        18     MALHADA DOS BOIS
# 4       240         RONDONOPOLIS
# ...     ...                  ...
# 47698  13,6      AGUAS VERMELHAS
# 47699   422            ALPERCATA
# 47700   234       ESTANCIA VELHA
# 47701   515   RIBEIRAO DAS NEVES
# 47702   388  OURO PRETO DO OESTE
#
#                                           causa_acidente  ...     longitude  \
# 0                                 Ultrapassagem Indevida  ...     -39,92379
# 1                            Manobra de mudança de faixa  ...  -41,76732659
# 2                       Ingestão de álcool pelo condutor  ...   -39,9611107
# 3               Reação tardia ou ineficiente do condutor  ...  -36,90552235
# 4      Condutor deixou de manter distância do veículo...  ...  -54,78905337
# ...                                                  ...  ...           ...
# 47698           Reação tardia ou ineficiente do condutor  ...    -41,359894
# 47699                                   Animais na Pista  ...  -41,95682514
# 47700                                   Acesso irregular  ...   -51,1444433
# 47701  Condutor deixou de manter distância do veículo...  ...  -44,09493479
# 47702                     Ausência de reação do condutor  ...  -62,26238327
#
#       regional delegacia             uop causa_principal ordem_tipo_acidente  \
# 0      SPRF-ES  DEL04-ES  UOP02-DEL04-ES             NaN                 NaN
# 1      SPRF-PI  DEL02-PI  UOP01-DEL02-PI             NaN                 NaN
# 2      SPRF-BA  DEL03-BA  UOP02-DEL03-BA             NaN                 NaN
# 3      SPRF-SE  DEL02-SE  UOP02-DEL02-SE             NaN                 NaN
# 4      SPRF-MT  DEL02-MT  UOP01-DEL02-MT             NaN                 NaN
# ...        ...       ...             ...             ...                 ...
# 47698  SPRF-BA  DEL08-BA  UOP03-DEL08-BA             NaN                 NaN
# 47699  SPRF-MG  DEL06-MG  UOP01-DEL06-MG             NaN                 NaN
# 47700  SPRF-RS  DEL01-RS  UOP02-DEL01-RS             NaN                 NaN
# 47701  SPRF-MG  DEL01-MG  UOP02-DEL01-MG             NaN                 NaN
# 47702  SPRF-RO  DEL03-RO  UOP02-DEL03-RO             NaN                 NaN
#
#       pessoas ignorados  feridos veiculos
# 0         NaN       NaN      NaN      NaN
# 1         NaN       NaN      NaN      NaN
# 2         NaN       NaN      NaN      NaN
# 3         NaN       NaN      NaN      NaN
# 4         NaN       NaN      NaN      NaN
# ...       ...       ...      ...      ...
# 47698     1.0       0.0      1.0      1.0
# 47699     1.0       0.0      1.0      1.0
# 47700     2.0       0.0      0.0      2.0
# 47701     3.0       0.0      2.0      3.0
# 47702     5.0       0.0      2.0      2.0
#
# [519241 rows x 41 columns]

# %%
df_concat.head(20)
# Out:
#           id      pesid data_inversa     dia_semana   horario  uf     br  \
# 0   571789.0  1269011.0   2024-01-01  segunda-feira  03:56:00  ES  101.0
# 1   571804.0  1269118.0   2024-01-01  segunda-feira  04:50:00  PI  343.0
# 2   571806.0  1269735.0   2024-01-01  segunda-feira  04:30:00  BA  116.0
# 3   571818.0  1269075.0   2024-01-01  segunda-feira  06:30:00  SE  101.0
# 4   571838.0  1269159.0   2024-01-01  segunda-feira  05:00:00  MT  364.0
# 5   571855.0  1269377.0   2024-01-01  segunda-feira  11:50:00  MG  251.0
# 6   571910.0  1269450.0   2024-01-01  segunda-feira  15:45:00  BA  116.0
# 7   571910.0  1269378.0   2024-01-01  segunda-feira  15:45:00  BA  116.0
# 8   571922.0  1269387.0   2024-01-01  segunda-feira  15:30:00  MG  251.0
# 9   571949.0  1269423.0   2024-01-01  segunda-feira  18:10:00  SP  116.0
# 10  571957.0  1269368.0   2024-01-01  segunda-feira  13:30:00  MG  262.0
# 11  571963.0  1269445.0   2024-01-01  segunda-feira  17:30:00  MT  364.0
# 12  571976.0  1269365.0   2024-01-01  segunda-feira  15:00:00  PR  376.0
# 13  571976.0  1269369.0   2024-01-01  segunda-feira  15:00:00  PR  376.0
# 14  571998.0  1269485.0   2024-01-01  segunda-feira  19:00:00  MS  163.0
# 15  571998.0  1269486.0   2024-01-01  segunda-feira  19:00:00  MS  163.0
# 16  572011.0  1269632.0   2024-01-01  segunda-feira  21:40:00  MT  364.0
# 17  572014.0  1269533.0   2024-01-01  segunda-feira  23:50:00  BA  101.0
# 18  572014.0  1271661.0   2024-01-01  segunda-feira  23:50:00  BA  101.0
# 19  572015.0  1269525.0   2024-01-01  segunda-feira  22:30:00  RS  101.0
#
#        km             municipio  \
# 0      38    CONCEICAO DA BARRA
# 1     185              PIRIPIRI
# 2     578               BREJOES
# 3      18      MALHADA DOS BOIS
# 4     240          RONDONOPOLIS
# 5     447            GRAO MOGOL
# 6   852,9  VITORIA DA CONQUISTA
# 7   852,9  VITORIA DA CONQUISTA
# 8   459,7            GRAO MOGOL
# 9     550        BARRA DO TURVO
# 10  594,4          CAMPOS ALTOS
# 11    396                CUIABA
# 12    327            ORTIGUEIRA
# 13    327            ORTIGUEIRA
# 14    551          BANDEIRANTES
# 15    551          BANDEIRANTES
# 16    542         ROSARIO OESTE
# 17    733               ITABELA
# 18    733               ITABELA
# 19     22       TRES CACHOEIRAS
#
#                                        causa_acidente  ...     longitude  \
# 0                              Ultrapassagem Indevida  ...     -39,92379
# 1                         Manobra de mudança de faixa  ...  -41,76732659
# 2                    Ingestão de álcool pelo condutor  ...   -39,9611107
# 3            Reação tardia ou ineficiente do condutor  ...  -36,90552235
# 4   Condutor deixou de manter distância do veículo...  ...  -54,78905337
# 5                             Velocidade Incompatível  ...  -43,27992195
# 6                                               Chuva  ...  -40,94931289
# 7                                               Chuva  ...  -40,94931289
# 8                                   Condutor Dormindo  ...    -43,368613
# 9            Reação tardia ou ineficiente do condutor  ...  -48,46440871
# 10                                 Pista Escorregadia  ...  -46,16901785
# 11                             Ultrapassagem Indevida  ...  -55,90523988
# 12           Reação tardia ou ineficiente do condutor  ...   -51,0643217
# 13           Reação tardia ou ineficiente do condutor  ...   -51,0643217
# 14                     Ausência de reação do condutor  ...  -54,37326248
# 15                     Ausência de reação do condutor  ...  -54,37326248
# 16  Acessar a via sem observar a presença dos outr...  ...  -56,44175649
# 17                             Transitar na contramão  ...    -39,577433
# 18                             Transitar na contramão  ...    -39,577433
# 19                     Ausência de reação do condutor  ...  -49,90113887
#
#    regional delegacia             uop causa_principal ordem_tipo_acidente  \
# 0   SPRF-ES  DEL04-ES  UOP02-DEL04-ES             NaN                 NaN
# 1   SPRF-PI  DEL02-PI  UOP01-DEL02-PI             NaN                 NaN
# 2   SPRF-BA  DEL03-BA  UOP02-DEL03-BA             NaN                 NaN
# 3   SPRF-SE  DEL02-SE  UOP02-DEL02-SE             NaN                 NaN
# 4   SPRF-MT  DEL02-MT  UOP01-DEL02-MT             NaN                 NaN
# 5   SPRF-MG  DEL12-MG  UOP01-DEL12-MG             NaN                 NaN
# 6   SPRF-BA  DEL08-BA  UOP01-DEL08-BA             NaN                 NaN
# 7   SPRF-BA  DEL08-BA  UOP01-DEL08-BA             NaN                 NaN
# 8   SPRF-MG  DEL12-MG  UOP01-DEL12-MG             NaN                 NaN
# 9   SPRF-SP  DEL05-SP  UOP02-DEL05-SP             NaN                 NaN
# 10  SPRF-MG  DEL08-MG  UOP02-DEL08-MG             NaN                 NaN
# 11  SPRF-MT  DEL01-MT  UOP02-DEL01-MT             NaN                 NaN
# 12  SPRF-PR  DEL07-PR  UOP02-DEL07-PR             NaN                 NaN
# 13  SPRF-PR  DEL07-PR  UOP02-DEL07-PR             NaN                 NaN
# 14  SPRF-MS  DEL01-MS  UOP02-DEL01-MS             NaN                 NaN
# 15  SPRF-MS  DEL01-MS  UOP02-DEL01-MS             NaN                 NaN
# 16  SPRF-MT  DEL01-MT  UOP01-DEL01-MT             NaN                 NaN
# 17  SPRF-BA  DEL09-BA  UOP01-DEL09-BA             NaN                 NaN
# 18  SPRF-BA  DEL09-BA  UOP01-DEL09-BA             NaN                 NaN
# 19  SPRF-RS  DEL03-RS  UOP02-DEL03-RS             NaN                 NaN
#
#    pessoas ignorados  feridos veiculos
# 0      NaN       NaN      NaN      NaN
# 1      NaN       NaN      NaN      NaN
# 2      NaN       NaN      NaN      NaN
# 3      NaN       NaN      NaN      NaN
# 4      NaN       NaN      NaN      NaN
# 5      NaN       NaN      NaN      NaN
# 6      NaN       NaN      NaN      NaN
# 7      NaN       NaN      NaN      NaN
# 8      NaN       NaN      NaN      NaN
# 9      NaN       NaN      NaN      NaN
# 10     NaN       NaN      NaN      NaN
# 11     NaN       NaN      NaN      NaN
# 12     NaN       NaN      NaN      NaN
# 13     NaN       NaN      NaN      NaN
# 14     NaN       NaN      NaN      NaN
# 15     NaN       NaN      NaN      NaN
# 16     NaN       NaN      NaN      NaN
# 17     NaN       NaN      NaN      NaN
# 18     NaN       NaN      NaN      NaN
# 19     NaN       NaN      NaN      NaN
#
# [20 rows x 41 columns]

# %%
contador = 1
df_concatenado = lista_dataframe[0]
for i in lista_dataframe[1:]:
  df_concatenado = pd.concat([df_concatenado , lista_dataframe[contador]])
  contador += 1

# %%
df_concatenado
# Out:
#              id      pesid data_inversa     dia_semana   horario  uf     br  \
# 0      571789.0  1269011.0   2024-01-01  segunda-feira  03:56:00  ES  101.0
# 1      571804.0  1269118.0   2024-01-01  segunda-feira  04:50:00  PI  343.0
# 2      571806.0  1269735.0   2024-01-01  segunda-feira  04:30:00  BA  116.0
# 3      571818.0  1269075.0   2024-01-01  segunda-feira  06:30:00  SE  101.0
# 4      571838.0  1269159.0   2024-01-01  segunda-feira  05:00:00  MT  364.0
# ...         ...        ...          ...            ...       ...  ..    ...
# 47698  627756.0        NaN   2024-08-20    terça-feira  17:00:00  MG  116.0
# 47699  627773.0        NaN   2024-06-01         sábado  19:20:00  MG  116.0
# 47700  627777.0        NaN   2024-08-07   quarta-feira  18:10:00  RS  116.0
# 47701  627911.0        NaN   2024-08-29   quinta-feira  07:30:00  MG   40.0
# 47702  627985.0        NaN   2024-07-14        domingo  23:30:00  RO  364.0
#
#          km            municipio  \
# 0        38   CONCEICAO DA BARRA
# 1       185             PIRIPIRI
# 2       578              BREJOES
# 3        18     MALHADA DOS BOIS
# 4       240         RONDONOPOLIS
# ...     ...                  ...
# 47698  13,6      AGUAS VERMELHAS
# 47699   422            ALPERCATA
# 47700   234       ESTANCIA VELHA
# 47701   515   RIBEIRAO DAS NEVES
# 47702   388  OURO PRETO DO OESTE
#
#                                           causa_acidente  ...     longitude  \
# 0                                 Ultrapassagem Indevida  ...     -39,92379
# 1                            Manobra de mudança de faixa  ...  -41,76732659
# 2                       Ingestão de álcool pelo condutor  ...   -39,9611107
# 3               Reação tardia ou ineficiente do condutor  ...  -36,90552235
# 4      Condutor deixou de manter distância do veículo...  ...  -54,78905337
# ...                                                  ...  ...           ...
# 47698           Reação tardia ou ineficiente do condutor  ...    -41,359894
# 47699                                   Animais na Pista  ...  -41,95682514
# 47700                                   Acesso irregular  ...   -51,1444433
# 47701  Condutor deixou de manter distância do veículo...  ...  -44,09493479
# 47702                     Ausência de reação do condutor  ...  -62,26238327
#
#       regional delegacia             uop causa_principal ordem_tipo_acidente  \
# 0      SPRF-ES  DEL04-ES  UOP02-DEL04-ES             NaN                 NaN
# 1      SPRF-PI  DEL02-PI  UOP01-DEL02-PI             NaN                 NaN
# 2      SPRF-BA  DEL03-BA  UOP02-DEL03-BA             NaN                 NaN
# 3      SPRF-SE  DEL02-SE  UOP02-DEL02-SE             NaN                 NaN
# 4      SPRF-MT  DEL02-MT  UOP01-DEL02-MT             NaN                 NaN
# ...        ...       ...             ...             ...                 ...
# 47698  SPRF-BA  DEL08-BA  UOP03-DEL08-BA             NaN                 NaN
# 47699  SPRF-MG  DEL06-MG  UOP01-DEL06-MG             NaN                 NaN
# 47700  SPRF-RS  DEL01-RS  UOP02-DEL01-RS             NaN                 NaN
# 47701  SPRF-MG  DEL01-MG  UOP02-DEL01-MG             NaN                 NaN
# 47702  SPRF-RO  DEL03-RO  UOP02-DEL03-RO             NaN                 NaN
#
#       pessoas ignorados  feridos veiculos
# 0         NaN       NaN      NaN      NaN
# 1         NaN       NaN      NaN      NaN
# 2         NaN       NaN      NaN      NaN
# 3         NaN       NaN      NaN      NaN
# 4         NaN       NaN      NaN      NaN
# ...       ...       ...      ...      ...
# 47698     1.0       0.0      1.0      1.0
# 47699     1.0       0.0      1.0      1.0
# 47700     2.0       0.0      0.0      2.0
# 47701     3.0       0.0      2.0      3.0
# 47702     5.0       0.0      2.0      2.0
#
# [519241 rows x 41 columns]
